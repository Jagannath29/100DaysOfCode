# %% [markdown]
# ## All the lifecycle in a data science project
#
# 1. Data Analysis
# 2. Feature Engineering
# 3. Feature Selection
# 4. Model Building
# 5. Model Deployment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Aim here is to understand the dataset

data = pd.read_csv('train.csv')
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# Lets see the shape of the dataset
data.shape
# Out:
# (1460, 81)

# %%
# To display all the columns 
pd.set_option('display.max_columns', None)

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ## What do we actually do in data analysis:
# - Missing Values
# - All the numerical variables
# - Distribution of the numerical variables
# - Categorical Variables
# - Cardinality of categorical variables
# - Outliers detection
# - Relation between independent and dependent features(Sale_price).

# %%
# Lets find the missing values first

data.isna()
# Out:
#          Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     False       False     False        False    False   False   True
# 1     False       False     False        False    False   False   True
# 2     False       False     False        False    False   False   True
# 3     False       False     False        False    False   False   True
# 4     False       False     False        False    False   False   True
# ...     ...         ...       ...          ...      ...     ...    ...
# 1455  False       False     False        False    False   False   True
# 1456  False       False     False        False    False   False   True
# 1457  False       False     False        False    False   False   True
# 1458  False       False     False        False    False   False   True
# 1459  False       False     False        False    False   False   True
#
#       LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# ...

# %%
data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# There are more null values in the column that we cannot see. Let's try another way to see.

# %%
null_features = [features for features in data.columns if data[features].isnull().sum()>1]

null_features
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
# Letssee how much missing values above column has

for features in null_features:
    print(f'{features}: {np.round(data[features].isnull().sum())}')
# Out:
# LotFrontage: 259
# Alley: 1369
# MasVnrType: 872
# MasVnrArea: 8
# BsmtQual: 37
# BsmtCond: 37
# BsmtExposure: 38
# BsmtFinType1: 37
# BsmtFinType2: 38
# FireplaceQu: 690
# GarageType: 81
# GarageYrBlt: 81
# GarageFinish: 81
# GarageQual: 81
# GarageCond: 81
# PoolQC: 1453
# Fence: 1179
# MiscFeature: 1406

# %% [markdown]
# ### Since there are lots of missing values. We need to find relationship between missing values and dependent features (sales_price) in our case.

# %%
for feature in null_features:
    df = data.copy() # copied becuse it doesen't effect our data 

    # If the feature is null we represent it with 1 else with 0.
    df[feature] = np.where(df[feature].isnull(), 1, 0)

    df.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# Missing values are clearly affecting our sale_price. So we need to fill those missing values with proper values, We will do that in feature engineering.

# %% [markdown]
# ## Numerical variables

# %%
numerical_features = [feature for feature in data.columns if data[feature].dtypes != 'O']

print(f'Length of the numerical features is: {len(numerical_features)}')

data[numerical_features].head()
# Out:
# Length of the numerical features is: 38
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %% [markdown]
# So, out of 81 features we 38 features are numerical type
#
# ### Temporal Variables(Eg: Datetime Variables)
#
#
# From the Dataset we have 4 year variables. We have extract information from the datetime variables like no of years or no of days. One example in this specific scenario can be difference in years between the year the house was built and the year the house was sold. We will be performing this analysis in the Feature Engineering which is the next video.

# %%
# List of variables that contain year features
year_feature = [year for year in numerical_features if 'Yr' in year or 'Year' in year]
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
# print unique values in year_feature

for year in year_feature:
    print(f'Unique values for {year} is {data[year].unique()}')
# Out:
# Unique values for YearBuilt is [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# Unique values for YearRemodAdd is [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
# Let's see if there is relationship between year sold and the price

data.groupby('YrSold')['SalePrice'].median().plot()

plt.xlabel('Year sold')
plt.ylabel('median house price')
plt.title('Year sold vs Price')
# Out:
# Text(0.5, 1.0, 'Year sold vs Price')

# %%
# Compare all year feature with sold_price

for year in year_feature:

    if year != 'YrSold':
        df = data.copy()

        # Difference between year variable and year the house is sold.

        df[year]=df['YrSold'] - df[year]


        plt.scatter(df[year], df['SalePrice'])
        plt.xlabel('feature')
        plt.ylabel('price')
        plt.show()

# %%
# Numerical variables are basically two types: 1. continuous and discrete.

discrete = [dis_feature for dis_feature in numerical_features if len(data[dis_feature].unique())<25 and dis_feature not in year_feature + ['Id']]
discrete
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
data[discrete].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# ...

# %%
# Relationship between discrete features and price

for dis_feature in discrete:
    df = data.copy()

    df.groupby(dis_feature)['SalePrice'].median().plot.bar()

    plt.xlabel(dis_feature)
    plt.ylabel('Price')
    plt.title(dis_feature)

    plt.show()

# %%
continuous = [cont_features for cont_features in numerical_features if cont_features not in discrete+year_feature+['Id']]
continuous
# Out:
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
data[continuous].head()
# Out:
#    LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0         65.0     8450       196.0         706           0        150
# 1         80.0     9600         0.0         978           0        284
# 2         68.0    11250       162.0         486           0        434
# 3         60.0     9550         0.0         216           0        540
# 4         84.0    14260       350.0         655           0        490
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  GarageArea  WoodDeckSF  \
# 0          856       856       854       1710         548           0
# 1         1262      1262         0       1262         460         298
# 2          920       920       866       1786         608           0
# 3          756       961       756       1717         642           0
# 4         1145      1145      1053       2198         836         192
#
#    OpenPorchSF  EnclosedPorch  ScreenPorch  SalePrice
# 0           61              0            0     208500
# ...

# %%
# Lets analyze the continuous values by creating the histograms to understand the distribution. 

for cont_feature in continuous:
    df = data.copy()

    df[cont_feature].hist(bins=25)

    plt.xlabel(cont_feature)
    plt.ylabel('Count')
    plt.title(cont_feature)

    plt.show()

# %% [markdown]
# - Saleprice is right skewed meaning price is increasing and increasing to 700000, but in real word price of the house can be even more than that.
# - To resolve we will be using log normal distribution.

# %% [markdown]
# ### Exploratory Data Analysis Part-2

# %%
# We will be using logarithmic transformation.

for feature in continuous:
    df2 = data.copy()
    if 0 in df2[feature].unique():
        pass
    else:
        df2[feature] = np.log(df2[feature])
        df2['SalePrice'] = np.log(df2['SalePrice'])

        plt.scatter(df2[feature], df2['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.title(feature)
        plt.show()

# %% [markdown]
# ## Outliers

# %%
for feature in continuous:
    if 0 not in df2[feature].unique():
        df2[feature] = np.log(df2[feature])

        df2.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)

        plt.show()
# Out:
# /home/ubuntu/100DaysOfCoding/100Venv/lib/python3.10/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ## Categorical features

# %%
categorical_features = [feature for feature in data.columns if data[feature].dtypes == 'O']

print(f'Length of the numerical features is: {len(categorical_features)}')

data[categorical_features].head()
# Out:
# Length of the numerical features is: 43
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %%
# unique in categorical_feature
for categorical in categorical_features:
    print(f'Unique values for {categorical} is {len(data[categorical].unique())}')
# Out:
# Unique values for MSZoning is 5
# Unique values for Street is 2
# Unique values for Alley is 3
# Unique values for LotShape is 4
# Unique values for LandContour is 4
# Unique values for Utilities is 2
# Unique values for LotConfig is 5
# Unique values for LandSlope is 3
# Unique values for Neighborhood is 25
# Unique values for Condition1 is 9
# Unique values for Condition2 is 8
# Unique values for BldgType is 5
# Unique values for HouseStyle is 8
# Unique values for RoofStyle is 6
# Unique values for RoofMatl is 8
# Unique values for Exterior1st is 15
# Unique values for Exterior2nd is 16
# Unique values for MasVnrType is 4
# Unique values for ExterQual is 4
# Unique values for ExterCond is 5
# Unique values for Foundation is 6
# Unique values for BsmtQual is 5
# Unique values for BsmtCond is 5
# Unique values for BsmtExposure is 5
# Unique values for BsmtFinType1 is 7
# Unique values for BsmtFinType2 is 7
# Unique values for Heating is 6
# Unique values for HeatingQC is 5
# ...

# %%
for feature in categorical_features:
    dff = data.copy()
    dff.groupby(feature)['SalePrice'].median().plot.bar()

    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()
