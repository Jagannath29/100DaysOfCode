# %%
# importing libraries
import pandas as pd
import csv

# %%
# with open('weather_data.csv', 'r') as file:
#     read = csv.reader(file)
#     df = list(read)
#     dataframe = pd.DataFrame(df)
#     print(dataframe[2:])
  
df = pd.read_csv('weather_data.csv', skiprows=2)
df.head()
# Out:
#         day    temperature     windspeed     event
# 0  1/1/2017             32             6      Rain
# 1  1/4/2017  not available             9     Sunny
# 2  1/5/2017             -1  not measured      Snow
# 3  1/6/2017  not available             7  no event
# 4  1/7/2017             32  not measured      Rain

# %%
# Statical status of the dataframe
df.describe()
# Out:
#               day    temperature     windspeed  event
# count          13             13            13     13
# unique         12              8             7      6
# top     1/11/2017  not available  not measured  Sunny
# freq            2              4             4      4

# %%
# Shape of the dataframe
df.shape
# Out:
# (13, 4)

# %% [markdown]
# ### Dataframe consists of 13 rows and 4 comluns

# %% [markdown]
# ### Import-85.data is a raw thas doesn't have column. I read the dataset using csv reader and give proper column name to the dataframe.

# %%
from csv import reader

data = open('imports-85.data', 'r') 
read_file = reader(data)
lst_of_data = list(read_file)

# %%
i_columns = ['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration', 'num_of_doors',
          'body_style', 'drive_wheels', 'engine_location', 'wheel_base', 'length', 'width', 
           'height', 'curb_weight', 'engine_type', 'num_of_cylinders', 'engine_size', 'fuel_system',
          'bore', 'stroke', 'compression', 'horsepower', 'peak_rpm', 'city_mpg', 'highway_mpg', 
           'price']

# %%
df = pd.DataFrame(lst_of_data, columns=i_columns).head()

# %%
df
# Out:
#   symboling normalized_losses         make fuel_type aspiration num_of_doors  \
# 0         3                 ?  alfa-romero       gas        std          two
# 1         3                 ?  alfa-romero       gas        std          two
# 2         1                 ?  alfa-romero       gas        std          two
# 3         2               164         audi       gas        std         four
# 4         2               164         audi       gas        std         four
#
#     body_style drive_wheels engine_location wheel_base  ... engine_size  \
# 0  convertible          rwd           front      88.60  ...         130
# 1  convertible          rwd           front      88.60  ...         130
# 2    hatchback          rwd           front      94.50  ...         152
# 3        sedan          fwd           front      99.80  ...         109
# 4        sedan          4wd           front      99.40  ...         136
#
# ...

# %%
df.shape
# Out:
# (5, 26)

# %%
# contains Null values or not
df.isnull().sum()
# Out:
# symboling            0
# normalized_losses    0
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         0
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# bore                 0
# stroke               0
# compression          0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                0
# dtype: int64

# %%
df.isna()
# Out:
#    symboling  normalized_losses   make  fuel_type  aspiration  num_of_doors  \
# 0      False              False  False      False       False         False
# 1      False              False  False      False       False         False
# 2      False              False  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False              False  False      False       False         False
#
#    body_style  drive_wheels  engine_location  wheel_base  ...  engine_size  \
# 0       False         False            False       False  ...        False
# 1       False         False            False       False  ...        False
# 2       False         False            False       False  ...        False
# 3       False         False            False       False  ...        False
# 4       False         False            False       False  ...        False
#
# ...
